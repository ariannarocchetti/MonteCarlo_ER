# %%
#teflon
#U238
0.003 + 0.00069 + 0.00023  + 1.9e-06
# Out:
# 0.0039219

# %%
#40
0.0071  +0.0005  +0.076 +4.4e-05
# Out:
# 0.083644

# %%
#cs137
0.00046  + 0.00057 + 0.0013 + 7.8e-07
# Out:
# 0.00233078

# %%
#th228
0.0024 + 0.0011 + 0.0021 + 2.4e-06
# Out:
# 0.005602399999999999

# %%
#U235
0.011 + 0.007 + 0.013 + 6.8e-07
# Out:
# 0.03100068

# %%
#Th232
0.0098 + 0.0007 + 0.0046 + 0.0046
# Out:
# 0.0197

# %%
#ra226
0.007  + 0.0077 + 0.0025 + 5.1e-06
# Out:
# 0.0172051

# %%
#copper 
#u238
0.0018  + 0.005 + 0.019 + 0.033
# Out:
# 0.058800000000000005

# %%
#co60
0.001 + 0.37 + 0.022
# Out:
# 0.393

# %%
#k40
0.00074 + 0.0042 + 0.013
# Out:
# 0.017939999999999998

# %%
#cs137
0.00021 + 0.00045 + 0.00046
# Out:
# 0.00112

# %%
#th228
0.0027 + 0.0015  + 0.00065 + 0.00077
# Out:
# 0.00562

# %%
#u235
7.9e-05 + 0.00069 + 0.016 + 0.0076
# Out:
# 0.024369

# %%
#th232
0.0039  + 0.0053  + 0.0012 + 0.0073
# Out:
# 0.0177

# %%
#ra226
0.0058 + 0.0046 + 0.0078
# Out:
# 0.0182

# %%
0.77+8.6+0.54+0.052+0.19+0.13+0.17+0.95
# Out:
# 11.402

# %%
0.16+1.21+0.09+0.009+0.048+0.067+0.031+0.13
# Out:
# 1.7449999999999997

# %%
0.004+0.08+0.002+0.006+0.031+0.02+0.017
# Out:
# 0.16000000000000003

# %%
0.059+0.39+0.018+0.001+0.006+0.024+ 0.018+0.018
# Out:
# 0.534

# %%
0.093 + 0.0029 + 3.8e-05
# Out:
# 0.095938

# %%
0.0095 + 2.1e-05 + 0.00012
# Out:
# 0.009641

# %%
0.046 +0.0017 + 0.00044
# Out:
# 0.04814

# %%
0.0039 + 0.00054 + 0.0023
# Out:
# 0.0067399999999999995

# %%
0.023 + 0.0077+  0.00032
# Out:
# 0.03102

# %%
0.12 + 0.013 + 0.00086
# Out:
# 0.13386

# %%
0.15+1.20+0.09+0.009+0.048+0.067+0.031+0.13
# Out:
# 1.7249999999999996

# %%
1.6 + 0.039 + 0.0091
# Out:
# 1.6481000000000001

# %%
0.15+1.20+0.09+0.009+0.048+0.0067+0.031+0.13
# Out:
# 1.6646999999999998

# %%
0.15+1.20+0.09+0.009+0.048+0.067+0.031+0.13
# Out:
# 1.7249999999999996

# %%
0.15 + 0.0032 + 0.0046
# Out:
# 0.1578

# %%
1.2  + 0.0093 + 0.00047
# Out:
# 1.20977

# %%
0.093 + 0.0029 + 3.8e-05
# Out:
# 0.095938

# %%
0.0095 + 2.1e-05 + 0.00012
# Out:
# 0.009641

# %%
0.046 + 0.0017 + 0.00044
# Out:
# 0.04814

# %%
0.0039 + 0.00054 + 0.0023
# Out:
# 0.0067399999999999995

# %%
0.54 + 0.09 + 0.08 + 0.018 + 5.5 + 2.3e-05
# Out:
# 6.228022999999999

# %%
0.052 + 0.009 + 0.002 + 0.001 + 0.052 + 1.9e-05
# Out:
# 0.116019

# %%
0.19 + 0.048 + 0.006 + 0.006 + 0.5 + 0.00034
# Out:
# 0.75034

# %%
0.13 + 0.006 + 0.031 + 0.024 + 0.02+ 0.00045
# Out:
# 0.21145

# %%
0.17 + 0.031 + 0.02+ 0.018 + 0.65 + 0.00019
# Out:
# 0.88919

# %%
0.95 + 0.13 + 0.017 + 0.018 + 1 + 0.00051
# Out:
# 2.11551

# %%
 4.38 + 14.05 + 6.22 +  0.116  + 0.75034 + 0.21 + 0.88919 + 2.11
# Out:
# 28.72553
