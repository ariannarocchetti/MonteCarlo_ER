# %%
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor

# %%
nb = nbformat.read(open("events_per_component_midwayedition.ipynb"), as_version=1)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-11a0928567bd> in <module>()
# ----> 1 nb = nbformat.read(open("events_per_component_midwayedition.ipynb"), as_version=1)
#
# /cvmfs/xenon.opensciencegrid.org/releases/anaconda/2.4/envs/pax_v6.10.1/lib/python3.4/site-packages/nbformat/__init__.py in read(fp, as_version, **kwargs)
#     139             return read(f, as_version, **kwargs)
#     140
# --> 141     return reads(fp.read(), as_version, **kwargs)
#     142
#     143
#
# /cvmfs/xenon.opensciencegrid.org/releases/anaconda/2.4/envs/pax_v6.10.1/lib/python3.4/encodings/ascii.py in decode(self, input, final)
#      24 class IncrementalDecoder(codecs.IncrementalDecoder):
#      25     def decode(self, input, final=False):
# ---> 26         return codecs.ascii_decode(input, self.errors)[0]
#      27
#      28 class StreamWriter(Codec,codecs.StreamWriter):
#
# ...

# %%
ep = ExecutePreprocessor(timeout=600, kernel_name='python3')
